# %% [markdown]
# # **Dataset injeção de falhas em rede quântica QKD**

# %% [markdown]
# Colab para realizar a análise exploratória dos dados dos datasets gerados pela simulação no SeQUeNCe, além do posterior treinamento de modelos para executar a detecção de falhas/ataques na rede quântica

# %% [markdown]
# ## Importações

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Análise exploratória do primeiro dataset gerado (teste_1)

# %%
df=pd.read_csv("/content/dataset_siteA_siteB.csv")

# %%
df
# Out:
#             t_ps             label  keys_buffer  qber_proxy  \
# 0              0            normal            0         NaN
# 1    20000000000            normal            0         NaN
# 2    40000000000            normal            0         NaN
# 3    60000000000            normal            0         NaN
# 4    80000000000            normal            0         NaN
# 5   100000000000            normal            0         NaN
# 6   120000000000            normal            0         NaN
# 7   140000000000            normal            0     0.00570
# 8   160000000000            normal            0     0.00570
# 9   180000000000            normal            0     0.00570
# 10  200000000000            normal            0     0.00570
# 11  220000000000            normal            0     0.00570
# 12  240000000000            normal            0     0.00570
# 13  260000000000            normal            0     0.00570
# 14  280000000000            normal            0     0.00575
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   t_ps               50 non-null     int64
#  1   label              50 non-null     object
#  2   keys_buffer        50 non-null     int64
#  3   qber_proxy         43 non-null     float64
#  4   throughput_bits_s  0 non-null      float64
#  5   latency_s          0 non-null      float64
#  6   disclosed_bits     50 non-null     int64
#  7   starvation_events  50 non-null     int64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 3.3+ KB
